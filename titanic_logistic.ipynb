# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('C:\\Users\\guru1_000\\Desktop\\coding ninza\\logistic regression-3\\project\\training_titanic_x_y_train.csv')
data.shape
# Out:
# (668, 11)

# %%
df=data.copy()
df.head()
# Out:
#    Pclass                                            Name     Sex   Age  \
# 0       2   Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.0
# 1       3               Williams, Mr. Howard Hugh "Harry"    male   NaN
# 2       2  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.0
# 3       3     Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0
# 4       3                          Sutehall, Mr. Henry Jr    male  25.0
#
#    SibSp  Parch           Ticket    Fare Cabin Embarked  Survived
# 0      1      0           228414  26.000   NaN        S         1
# 1      0      0         A/5 2466   8.050   NaN        S         0
# 2      0      0           250655  26.000   NaN        S         0
# 3      0      4           349909  21.075   NaN        S         0
# 4      0      0  SOTON/OQ 392076   7.050   NaN        S         0

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Pclass                                            Name     Sex   Age  \
# 0       2   Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.0
# 1       3               Williams, Mr. Howard Hugh "Harry"    male   NaN
# 2       2  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.0
# 3       3     Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0
# 4       3                          Sutehall, Mr. Henry Jr    male  25.0
#
#    SibSp  Parch           Ticket    Fare Embarked  Survived
# 0      1      0           228414  26.000        S         1
# 1      0      0         A/5 2466   8.050        S         0
# 2      0      0           250655  26.000        S         0
# 3      0      4           349909  21.075        S         0
# 4      0      0  SOTON/OQ 392076   7.050        S         0

# %%
df.drop('Ticket',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Pclass        0
# Name          0
# Sex           0
# Age         132
# SibSp         0
# Parch         0
# Fare          0
# Embarked      1
# Survived      0
# dtype: int64

# %%
df.shape
# Out:
# (668, 9)

# %%
df.head()
# Out:
#    Pclass                                            Name     Sex   Age  \
# 0       2   Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.0
# 1       3               Williams, Mr. Howard Hugh "Harry"    male   NaN
# 2       2  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.0
# 3       3     Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0
# 4       3                          Sutehall, Mr. Henry Jr    male  25.0
#
#    SibSp  Parch    Fare Embarked  Survived
# 0      1      0  26.000        S         1
# 1      0      0   8.050        S         0
# 2      0      0  26.000        S         0
# 3      0      4  21.075        S         0
# 4      0      0   7.050        S         0

# %%
del df["Fare"]

# %%
df.head()
# Out:
#    Pclass                                            Name     Sex   Age  \
# 0       2   Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.0
# 1       3               Williams, Mr. Howard Hugh "Harry"    male   NaN
# 2       2  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.0
# 3       3     Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0
# 4       3                          Sutehall, Mr. Henry Jr    male  25.0
#
#    SibSp  Parch Embarked  Survived
# 0      1      0        S         1
# 1      0      0        S         0
# 2      0      0        S         0
# 3      0      4        S         0
# 4      0      0        S         0

# %%
def getnum(str):
     if str=="male":
        return 1
     else:
        return 0

# %%
df["gender"]=df['Sex'].apply(getnum)

# %%
df.head()
# Out:
#    Pclass                                            Name     Sex   Age  \
# 0       2   Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.0
# 1       3               Williams, Mr. Howard Hugh "Harry"    male   NaN
# 2       2  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.0
# 3       3     Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0
# 4       3                          Sutehall, Mr. Henry Jr    male  25.0
#
#    SibSp  Parch Embarked  Survived  gender
# 0      1      0        S         1       0
# 1      0      0        S         0       1
# 2      0      0        S         0       1
# 3      0      4        S         0       0
# 4      0      0        S         0       1

# %%
del df["Sex"]
df.head()
# Out:
#    Pclass                                            Name   Age  SibSp  Parch  \
# 0       2   Weisz, Mrs. Leopold (Mathilde Francoise Pede)  29.0      1      0
# 1       3               Williams, Mr. Howard Hugh "Harry"   NaN      0      0
# 2       2  Morley, Mr. Henry Samuel ("Mr Henry Marshall")  39.0      0      0
# 3       3     Palsson, Mrs. Nils (Alma Cornelia Berglund)  29.0      0      4
# 4       3                          Sutehall, Mr. Henry Jr  25.0      0      0
#
#   Embarked  Survived  gender
# 0        S         1       0
# 1        S         0       1
# 2        S         0       1
# 3        S         0       0
# 4        S         0       1

# %%
del df['Name']
df.head()
# Out:
#    Pclass   Age  SibSp  Parch Embarked  Survived  gender
# 0       2  29.0      1      0        S         1       0
# 1       3   NaN      0      0        S         0       1
# 2       2  39.0      0      0        S         0       1
# 3       3  29.0      0      4        S         0       0
# 4       3  25.0      0      0        S         0       1

# %%
means=df[df.Survived==1].Age.mean()
means
# Out:
# 28.138157894736842

# %%
df["age"]=np.where(pd.isnull(df.Age) & df["Survived"]==1  ,means, df["Age"])
df.head()
# Out:
#    Pclass   Age  SibSp  Parch Embarked  Survived  gender   age
# 0       2  29.0      1      0        S         1       0  29.0
# 1       3   NaN      0      0        S         0       1   NaN
# 2       2  39.0      0      0        S         0       1  39.0
# 3       3  29.0      0      4        S         0       0  29.0
# 4       3  25.0      0      0        S         0       1  25.0

# %%
meanS=df[df.Survived==0].Age.mean()
meanS
# Out:
# 30.857142857142858

# %%
del df['Age']
df.head()
# Out:
#    Pclass  SibSp  Parch Embarked  Survived  gender   age
# 0       2      1      0        S         1       0  29.0
# 1       3      0      0        S         0       1   NaN
# 2       2      0      0        S         0       1  39.0
# 3       3      0      4        S         0       0  29.0
# 4       3      0      0        S         0       1  25.0

# %%
df.age.fillna(meanS,inplace=True)
df
# Out:
#      Pclass  SibSp  Parch Embarked  Survived  gender        age
# 0         2      1      0        S         1       0  29.000000
# 1         3      0      0        S         0       1  30.857143
# 2         2      0      0        S         0       1  39.000000
# 3         3      0      4        S         0       0  29.000000
# 4         3      0      0        S         0       1  25.000000
# 5         3      0      0        C         0       1  34.500000
# 6         1      1      0        S         1       0  35.000000
# 7         3      0      0        S         0       1  23.000000
# 8         2      0      0        S         1       1  28.138158
# 9         3      0      0        S         0       1  50.000000
# 10        3      0      0        S         1       0  23.000000
# 11        3      0      0        C         0       1  30.857143
# 12        2      0      0        S         0       1  36.000000
# 13        3      1      0        Q         0       1  30.857143
# ...

# %%
lr.score(test_data,y_test)

# %%
df.rename(columns={'age':'Age'},inplace=True)
df.rename(columns={'gender':'Sex'},inplace =True)
df.head()

# %%
def change(str):
    if str=='C':
        return 1
    elif str=='S':
        return 2
    else:
        return 3

df['embarked']=df['Embarked'].apply(change)
del df['Embarked']
df.rename(columns={'embarked':'Embarked'},inplace=True)
df.head()

# %%
feature=df['Survived']
feature.shape

# %%
df.head()

# %%
del df['Survived']
df.head()

# %%
df.head()

# %%
data_train=df
data_train.head()

# %%
data_train.shape

# %%
feature.shape

# %%
data_test=pd.read_csv('C:\\Users\\guru1_000\\Desktop\\coding ninza\\logistic regression-3\\project\\test_titanic_x_test.csv')
data_test.shape

# %%
data_test.head()

# %%
dff=data_test.copy()

# %%
del dff['Name']

# %%
del dff['Ticket']

# %%
del dff['Fare']

# %%
del dff['Cabin']

# %%
dff.head()

# %%
dff['gender']=dff['Sex'].apply(getnum)
dff.head()

# %%
dff.head()

# %%
dff.describe()

# %%
dff['age']=np.where(pd.isnull(dff.Age),means,dff['Age'])
dff.head()

# %%
del dff['Age']

# %%
del dff['Sex']

# %%
dff.head()

# %%
dff.rename(columns={'age':'Age'},inplace=True)
dff.rename(columns={'gender':'Sex'},inplace=True)

# %%
dff.head()

# %%
dff['embarked']=dff['Embarked'].apply(change)
del dff['Embarked']
dff.rename(columns={'embarked':'Embarked'},inplace=True)
dff.shape

# %%
df.columns=[0,1,2,3,4,5]

# %%
dff.columns=[0,1,2,3,4,5]

# %%
dff.head()

# %%
ar=['a','b','c','d','e','f']
df.shape

# %%
for i in range(6):
    for j in range(6):
        dff[ar[i]+ar[j]]=dff[i]*dff[j]
        df[ar[i]+ar[j]]=df[i]*df[j]
df.shape

# %%
data_train=df
data_train.head()

# %%
data_test1=dff
data_test1.head()

# %%
data_train.head()

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf1=LogisticRegression()

# %%
clf1.fit(data_train,feature)

# %%
y_pred=clf1.predict(data_test1)
y_pred

# %%
clf1.score(data_train,feature)

# %%
clf1.predict_proba(data_train)[665]

# %%
np.savetxt('C:\\Users\\guru1_000\\Desktop\\ml\\logistic regression-3\\y_pred.csv',y_pred,delimiter=",",fmt='%.5f')
